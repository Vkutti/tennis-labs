# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

data = pd.read_csv("atp_matches_2008.csv", low_memory=False, na_values=[' ', ''])

data.columns = data.columns.str.strip()

players = ['Tommy Haas', 'Juan Balcells', 'Alberto Martin', 'Juan Carlos Ferrero', 'Michael Chang', 'Magnus Gustafsson', 'Thomas Johansson', 'Sjeng Schalken', 'Tomas Behrend', 'Gaston Gaudio', 'Jiri Novak', 'Marc Rosset', 'John Van Lottum', 'Jan Michael Gambill', 'Magnus Norman', 'Andrea Gaudenzi', 'Albert Portas', 'Galo Blanco', 'Markus Hantschk', 'Andrei Medvedev', 'Christophe Rochus', 'Andrei Pavel', 'Juan Antonio Marin', 'Markus Hipfl', 'Stefan Koubek', 'Andrew Ilie', 'Sergi Bruguera', 'Thomas Enqvist', 'Ivan Ljubicic', 'Slava Dosedel', 'Bohdan Ulihrach', 'Jonas Bjorkman', 'Fernando Meligeni', 'Max Mirnyi', 'Franco Squillari', 'Richard Fromberg', 'Younes El Aynaoui', 'Antony Dupuis', 'Gianluca Pozzi', 'Greg Rusedski', 'Julien Boutter', 'Justin Gimelstob', 'Fabrice Santoro', 'Mark Philippoussis', 'Goran Ivanisevic', 'Karol Kucera', 'Byron Black', 'Sebastien Grosjean', 'Davide Sanguinetti', 'Todd Martin', 'Andre Sa', 'Michael Llodra', 'Andre Agassi', 'Marat Safin', 'Cedric Pioline', 'Lleyton Hewitt', 'Pete Sampras', 'Alex Corretja', 'Vincent Spadea', 'George Bastl', 'Marcelo Rios', 'Francisco Clavet', 'Jerome Golmard', 'Albert Costa', 'Mariano Puerta', 'Felix Mantilla', 'Nicolas Kiefer', 'Chris Woodruff', 'Mardy Fish', 'Wayne Arthurs', 'Peter Wessels', 'David Prinosil', 'Jason Stoltenberg', 'Paul Goldstein', 'Scott Draper', 'Jiri Vanek', 'Nicolas Massu', 'Andreas Vinciguerra', 'Guillermo Canas', 'Dominik Hrbaty', 'Adrian Voinea', 'Alex Calatrava', 'Raemon Sluiter', 'Arnaud Di Pasquale', 'Sergio Roitman', 'Jan Siemerink', 'Nikolay Davydenko', 'Sargis Sargsian', 'Paul Henri Mathieu', 'Michel Kratochvil', 'Agustin Calleri', 'Federico Luzzi', 'Fernando Gonzalez', 'Yevgeny Kafelnikov', 'Nicolas Lapentti', 'Mariano Zabaleta', 'Rainer Schuettler', 'Karim Alami', 'David Sanchez', 'Olivier Rochus', 'Alexander Popp', 'Mikael Tillstrom', 'Hicham Arazi', 'Carlos Moya', 'Nicolas Escude', 'Roger Federer', 'Richard Krajicek', 'Arnaud Clement', 'Tim Henman', 'Leander Paes', 'Takao Suzuki', 'Cecil Mamiit', 'Harel Levy', 'Hyung Taik Lee', 'Wayne Black', 'Gustavo Kuerten', 'Patrick Rafter', 'Kevin Kim', 'Fernando Vicente', 'Jean Rene Lisnard', 'Wayne Ferreira', 'Juan Ignacio Chela', 'Tomas Zib', 'Paradorn Srichaphan', 'Magnus Larsson', 'Andy Roddick', 'Cyril Saulnier', 'Xavier Malisse', 'Michal Tabara', 'Guillermo Coria', 'Taylor Dent', 'Vladimir Voltchk
in', 'Luca Vanni', 'Cem Ilkel', 'Alex Bolt', 'Salvatore Caruso', 'Sumit Nagal', 'Jason Jung', 'Prajnesh Gunneswaran', 'Nicolas Mejia', 'Chun Hsin Tseng', 'Emilio Nava', 'Zachary Svajda', 'Lukas Klein', 'Tomas Barrios Vera', 'Shintaro Mochizuki', 'Tristan Schoolkate', 'Hugo Grenier', 'Giulio Zeppieri', 'Francesco Passaro', 'Martin Landaluce', 'Otto Virtanen', 'Billy Harris', 'Jaime Faria', 'Nishesh Basavareddy', 'Valentin Royer']


w_all_data = []
l_all_data = []

court_types = ['Hard', 'Clay', 'Grass', 'Carpet']


for idx, row in data.iterrows():
    winner = str(row["winner_name"]).strip()
    loser = str(row["loser_name"]).strip()
    court_surface = str(row["surface"])

    # ignore unknown surfaces
    if court_surface not in court_types:
        continue

    for p in players:

        if winner == p:
            try:
                w_serve_to_points = float(row['w_svpt'])
                w_first_serves = float(row['w_1stWon'])
                w_second_serves = float(row['w_2ndWon'])
                w_aces = float(row['w_ace'])
                w_df = float(row['w_df'])

                if w_serve_to_points > 0:

                    w_serves_to_points = (w_first_serves + w_second_serves) / w_serve_to_points

                    l_return_accuracy = (w_serve_to_points - (w_first_serves + w_second_serves)) / w_serve_to_points

                    w_all_data.append([
                        p,
                        court_surface,
                        w_serves_to_points,
                        l_return_accuracy,
                        w_aces,
                        w_df,
                        1
                    ])

            except (ValueError, TypeError):
                continue


        if loser == p:
            try:
                l_serve_to_points = float(row['l_svpt'])
                l_first_serves = float(row['l_1stWon'])
                l_second_serves = float(row['l_2ndWon'])
                l_aces = float(row['l_ace'])
                l_df = float(row['l_df'])

                if l_serve_to_points > 0:

                    l_serves_to_points = (l_first_serves + l_second_serves) / l_serve_to_points

                    w_return_accuracy = (l_serve_to_points - (l_first_serves + l_second_serves)) / l_serve_to_points


                    l_all_data.append([
                        p,
                        court_surface,
                        l_serves_to_points,
                        w_return_accuracy,
                        l_aces,
                        l_df,
                        1
                    ])

            except (ValueError, TypeError):
                continue

total_all_data = w_all_data + l_all_data


total_all_data_dict = {
    p: {
        surface: {
            "serve": 0,
            "return": 0,
            "aces": 0,
            "df": 0,
            "matches": 0
        }
        for surface in court_types
    }
    for p in players
}

for i in total_all_data:

    player = i[0]
    surface = i[1]

    serve_value = i[2]
    return_value = i[3]
    aces = i[4]
    df = i[5]
    matches = i[6]


    if (
        player in total_all_data_dict 
        and surface in court_types
        and not math.isnan(serve_value)
        and not math.isnan(return_value)
    ):

        total_all_data_dict[player][surface]["serve"] += serve_value
        total_all_data_dict[player][surface]["return"] += return_value
        total_all_data_dict[player][surface]["aces"] += aces
        total_all_data_dict[player][surface]["df"] += df
        total_all_data_dict[player][surface]["matches"] += matches

import json

with open("player_surface_stats.json", "w") as file:
    json.dump(total_all_data_dict, file, indent=4)

# %%
"""

plt.figure(figsize=(30, 10))

for idx, (player, vals) in enumerate(total_all_data_dict.items()):
    serve_vals = vals["serve"]
    return_vals = vals["return"]
    aces_vals = vals["aces"]
    df_vals = vals["df"]
    if serve_vals and return_vals:
        avg_serve = sum(serve_vals) / len(serve_vals)
        avg_return = sum(return_vals) / len(return_vals)
        avg_aces = sum(aces_vals) / len(aces_vals)
        avg_df = sum(df_vals) / len(df_vals)
        print(f'["{player}", {avg_serve}, {avg_return}, {avg_aces}, {avg_df}],')
        plt.bar(idx - 0.5, avg_serve, width=0.25, label='Serve' if idx == 0 else "", color='turquoise')
        plt.bar(idx - 0.25, avg_return, width=0.25, label='Return' if idx == 0 else "", color='orange')
        plt.bar(idx + 0.0, avg_aces, width=0.25, label='Aces' if idx == 0 else "", color='green')
        plt.bar(idx + 0.25, avg_df, width=0.25, label='DF' if idx == 0 else "", color='red')
        plt.bar(idx + 0.5, avg_df, width=0.25, label='DF' if idx == 0 else "", color='white')


plt.xticks(range(len(players)), players)
plt.legend()
plt.tight_layout()
plt.show()


"""

# %%
players = []


for player in data["winner_name"].unique():
    matches_played = (list(data["winner_name"]).count(player))
    
    if matches_played > 4:
        players.append(player)

for player in data["loser_name"].unique():
    matches_played = (list(data["loser_name"]).count(player))

    if player not in players and matches_played > 4:
        players.append(player)

print((players))
# Out:
# ['Tommy Haas', 'Juan Balcells', 'Alberto Martin', 'Juan Carlos Ferrero', 'Michael Chang', 'Magnus Gustafsson', 'Thomas Johansson', 'Sjeng Schalken', 'Tomas Behrend', 'Gaston Gaudio', 'Jiri Novak', 'Marc Rosset', 'John Van Lottum', 'Jan Michael Gambill', 'Magnus Norman', 'Andrea Gaudenzi', 'Albert Portas', 'Galo Blanco', 'Markus Hantschk', 'Andrei Medvedev', 'Christophe Rochus', 'Andrei Pavel', 'Juan Antonio Marin', 'Markus Hipfl', 'Stefan Koubek', 'Andrew Ilie', 'Orlin Stanoytchev', 'Sergi Bruguera', 'Jeff Tarango', 'Thomas Enqvist', 'Ivan Ljubicic', 'Slava Dosedel', 'Bohdan Ulihrach', 'Federico Browne', 'Jonas Bjorkman', 'Fernando Meligeni', 'Gaston Etlis', 'Hernan Gumy', 'Max Mirnyi', 'Franco Squillari', 'Martin Damm Sr', 'Richard Fromberg', 'Younes El Aynaoui', 'Antony Dupuis', 'Gianluca Pozzi', 'Ronald Agenor', 'Greg Rusedski', 'Jens Knippschild', 'Julien Boutter', 'Justin Gimelstob', 'Fabrice Santoro', 'Mark Philippoussis', 'Goran Ivanisevic', 'Karol Kucera', 'Byron Black', 'Sebastien Grosjean', 'Davide Sanguinetti', 'Daniel Nestor', 'Bob Bryan', 'Todd Martin', 'Andre Sa', 'Michael Llodra', 'Arvind Parmar', 'Andre Agassi', 'Marat Safin', 'Cedric Pioline', 'Lleyton Hewitt', 'Pete Sampras', 'Alex Corretja', 'Vincent Spadea', 'George Bastl', 'Marcelo Rios', 'Francisco Clavet', 'Jerome Golmard', 'Albert Costa', 'Mariano Puerta', 'Felix Mantilla', 'Nicolas Kiefer', 'Chris Woodruff', 'Mardy Fish', 'Wayne Arthurs', 'Christian Vinck', 'Peter Wessels', 'David Prinosil', 'Jason Stoltenberg', 'Tuomas Ketola', 'Paul Goldstein', 'Laurence Tieleman', 'Scott Draper', 'Jiri Vanek', 'Nicolas Massu', 'Fredrik Jonsson', 'Christian Ruud', 'Andreas Vinciguerra', 'Guillermo Canas', 'Dominik Hrbaty', 'Edwin Kempes', 'Adrian Voinea', 'Dennis Van Scheppingen', 'Adrian Garcia', 'Alex Calatrava', 'Raemon Sluiter', 'Arnaud Di Pasquale', 'Sergio Roitman', 'Jan Siemerink', 'Nikolay Davydenko', 'Sargis Sargsian', 'Paul Henri Mathieu', 'Michel Kratochvil', 'Emilio Benfele Alvarez', 'Agustin Calleri', 'Federico Luzzi', 'Fernando Gonzalez', 'Yevgeny Kafelnikov', 'Nicolas Lapentti', 'Mariano Zabaleta', 'Daniel Elsner', 'Marc Kevin Goellner', 'Rainer Schuettler', 'Karim Alami', 'David Sanchez', 'Olivier Rochus', 'Diego Nargiso', 'Stephane Huet', 'Alexander Popp', 'Mikael Tillstrom', 'Juan Albert Viloca Puig', 'Hicham Arazi', 'Carlos Moya', 'Nicolas Escude', 'Roger Federer', 'Nicolas Thomann', 'Richard Krajicek', 'Arnaud Clement', 'Tim Henman', 'Leander Paes', 'Takao Suzuki', 'Cecil Mamiit', 'Eric Taino', 'Harel Levy', 'Hyung Taik Lee', 'Wayne Black', 'Gustavo Kuerten', 'Patrick Rafter', 'Kevin Kim', 'Fernando Vicente', 'Daniel Vacek', 'Jean Rene Lisnard', 'Wayne Ferreira', 'Juan Ignacio Chela', 'Tomas Zib', 'Martin Rodriguez', 'Nicolas Coutelot', 'Paradorn Srichaphan', 'Axel Pretzsch', 'Jeff Salzenstein', 'Magnus Larsson', 'Andy Roddick', 'Cyril Saulnier', 'Xavier Malisse', 'Michal Tabara', 'Todd Woodbridge', 'Michael Kohlmann', 'Lorenzo Manta', 'Guillermo Coria', 'Barry Cowan', 'Taylor Dent', 'Lionel Roux', 'Sebastien Lareau', 'Vladimir Voltchkov', 'Simon Larose', 'Jan Kroslak', 'Neville Godwin', 'Gouichi Motomura', 'Kevin Ullyett', 'Mikhail Youzhny', 'Lars Burgsmuller', 'German Puentes', 'Renzo Furlan', 'Attila Savolt', 'Andrei Stoliarov', 'Ivo Heuberger', 'Jacobo Diaz', 'Mike Bryan', 'Werner Eschauer', 'Martin Lee', 'Michael Russell', 'Razvan Sabau', 'Ramon Delgado', 'Jonathan Erlich', 'Jamie Delgado', 'Alejandro Hernandez', 'Kristian Pless', 'Jimy Szymanski', 'Jose De Armas', 'Luis Horna', 'Luis Adrian Morejon', 'Vadim Kutsenko', 'Oleg Ogorodov', 'Mark Nielsen', 'Jarkko Nieminen', 'Ben Qiang Zhu', 'Danai Udomchoke', 'Federico Dondo', 'Marcel Felder', 'Ricardo Chile Fonte', 'Aisam Ul Haq Qureshi', 'Suwandi Suwandi', 'Febi Widhiyanto', 'Mark Merklein', 'Michael Quintero', 'Wei Jen Cheng', 'Alexey Kedryuk', 'Wing Luen Wong', 'Johnny Arcilla', 'Anoosha Shahgholi', 'Mario Ancic', 'Lovro Zovko', 'Gilles Muller', 'Peter Clarke', 'Claude Ngoran', 'Karim Maamoun ...
